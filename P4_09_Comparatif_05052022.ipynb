# %% [markdown]
# # **Comparatif des métriques pour chaque méthode**
#
#
#
#
#
#
# <a name="Imports"></a>
# ## **Import des jeux de données** :

# %%
from ast import literal_eval 

import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)

import matplotlib.pyplot as plt
plt.style.use('ggplot')

import seaborn as sns
sns.set_style("whitegrid")
sns.color_palette("crest", as_cmap=True)

import statistics
import re
use_colab=True
if use_colab:
  from google.colab import drive
  drive.mount('/content/drive')
X_train = pd.read_csv('/content/drive/MyDrive/X_trainlog.csv',sep='\t')
X_test = pd.read_csv('/content/drive/MyDrive/X_testlog.csv',sep='\t')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd


MetCO2=pd.read_csv("/content/drive/MyDrive/MetC02_RegBoost.csv",sep='\t')
MetEn=pd.read_csv("/content/drive/MyDrive/MetEn_RegBoost.csv",sep='\t')

# %% [markdown]
# ## **Comparatif des métriques pour les émissions de CO2**

# %%
MetCO2=MetCO2[['MSE', 'R2','time']]
tax = ['Dummy','Regression Lin','Ridge','R.Forest','XGBoost']

MetCO2['Méthode'] = tax

# %%
MetCO2
# Out:
#         MSE        R2      time         Méthode
# 0  2.489447 -0.010528  0.058458           Dummy
# 1  2.430386  0.013446  0.248268  Regression Lin
# 2  0.943471  0.617022  0.074100           Ridge
# 3  0.180016  0.926927  0.393227        R.Forest
# 4  0.019760  0.991979  3.031379         XGBoost

# %% [markdown]
# ## **Comparatif des métriques pour la consommation d'énergie**

# %%
MetEn=MetEn[['MSE', 'R2','time']]


MetEn['Méthode'] = tax
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
MetEn
# Out:
#         MSE        R2      time         Méthode
# 0  1.813191 -0.006142  1.353211           Dummy
# 1  1.919232 -0.064984  1.675079  Regression Lin
# 2  0.943471  0.617022  0.074100           Ridge
# 3  0.180016  0.926927  0.393227        R.Forest
# 4  0.019760  0.991979  3.031379         XGBoost

# %% [markdown]
# On observe au final que la méthode Random Forest est donc bien la méthode la plus efficace ici.
