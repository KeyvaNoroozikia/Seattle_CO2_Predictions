# %% [markdown]
# #Emissions de CO2 à Seattle :
#
#
# Pour atteindre l'objectif de ville neutre en émissions de carbone en 2050, la ville de Seattle s’intéresse de près aux émissions des bâtiments non destinés à l’habitation.
#
# Des relevés minutieux ont été effectués en 2015 et en 2016. Cependant, ces relevés sont coûteux à obtenir, et à partir de ceux déjà réalisés, nous devons tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments pour lesquels elles n’ont pas encore été mesurées.
#
#
# Des explications sur les variables se trouvent sur le site suivant .
#
# Voyons les différentes unités des variables présentes dans notre dataframe de base.
#
#
#
# Pour mener à bien notre projet, nous allons suivre un plan précis détaillé dans le sommaire ci-dessous:
#
# #Sommaire
#
# 1. [Cleaning Notebook](#Introduction)
#
# 2. [Encodage des données](#Renommages)
#
# 3. [Dummy regressor](#Renommages1)
#
# 4. [Régression linéaire](#TraitementNans)
#
# 5. [Ridge](#createurs)
#
# 6. [Random Forest](#Random)
#
# 7. [XGBoost](#Boost)
#
# 8. [Comparatif des modèles](#mod)
#
# 9. [Influence de l'Energy Star Score](#mod)
#
# 10. [Conclusion](#Conclusion)

# %% [markdown]
# <a name="Introduction"></a>
# # Cleaning Notebook
#
# Voici le <A HREF="./1oyejWYumOdpKNkHVPa81U11AwL_6LjJG"> Notebook d'analyse des données</A>
#
# Pour commencer on va cleaner le dataframe de base pour nous débarasser des valeurs redondantes et traiter les valeurs manquantes afin d'avoir les meilleurs résultats possibles, le notebook est disponible ici
#
# Le notebook d'analyse nous a permis d'observer des corrélations entre plusieurs variables dont l'électricité et l'utilisation d'énergie. On se retrouve donc avec un dataframe réduit et nettoyé.
#
# Le British Thermal Unit ou BTU est une unité d'énergie frigorifique très utilisée dans les pays anglosaxons et en asie. Le BTU équivaut à 1055 Joules ou 252 calories. On a donc ici des Kilo British Thermal Unit, sf veut dire square feet, qui correspond aux mètres carrés qu'on retrouve d'ailleurs dans la taille et la surface des buildings. Quand à l'unité lbs elle désigne 1 Pound qui est équivalent à environ 0.45 Kg.
#
# Quant aux variables, SiteEnergyUse correspond à la consommation d'énergie d'un building, TotalGHGEmissions correspond aux emissions de CO2 du building et Primary et Secondary Largest Property Use Type référent à l'utilisation du buidling et ce dont à quoi il sert ( exemple : magasin )

# %% [markdown]
# <a name="Renommages"></a>
# #Encodage des données :
#
# Voici le <A HREF="./1FiLTqKkEkzvhwce7RX3JIwkjj9SHnnFV#scrollTo=GqVtBisAK5by"> Notebook d'encodage</A>
#
#
# Ce notebook va montrer le processus d'encodage des données. En effet, pour les variables catégorielles, avant de les intégrer dans un jeu d'entrainement(et de test) , on doit encoder les données et les mettre sous forme d'étiquettes.
# On va utiliser dans ce notebook le TargetEncoding, il consiste à prendre le nombre d'occurences ayant pour target le nombre 1, et de diviser ce nombre par le nombre d'occurences total de cette variable, on obtient donc un pourcentage qu'on va inclure dans notre jeu de données à la place de la variable.
#
# Ce notebook est disponible ici.

# %% [markdown]
# <a name="Renommages1"></a>
# #Dummy Regressor :
#
# Voici le <A HREF="./1R8TeosOu1DuaoNfezliU6-Ity_e62H90"> Notebook du Dummy Regressor</A>
#
#
#
# Cette méthode consiste à faire des prédictions en utilisant des règles simples, ici on utilise la moyenne dans notre modèle.

# %% [markdown]
# <a name="TraitementNans"></a>
# # Régression linéaire
#
# Voici le <A HREF="./1FpIELZD-_PdCKk7Mdq1mI77NLxgvzkkZ"> Notebook de Régression linéaire</A>
#
# Dans ce notebook, vu les relations qu'on a vues entre certaines variables via le cleaning notebook, on va utiliser un régression linéaire pour voir si on peut prédire la consommation de CO2 des buildings de Seattle, le notebook est disponible ici.
#
# Après examen, on observe que la marge d'erreur dans notre regression linéaire est trop elevée et cela peut s'expliquer par des multicolinéarités qu'on peut suspecter entre par exemple la consommation d'éléctricité et la consommation d'énergie des buildings. On va donc essayer d'améliorer notre modèle de base via un modèle Elastic Net.

# %% [markdown]
# <a name="createurs"></a>
# # Ridge
#
# Voici le <A HREF="./1O8QNBiL6psLbdPKAb2typTi6OMYdUnEX#scrollTo=mt-SBnnre-yO"> Notebook de Régression Ridge</A>
#
#
# Dans ce notebook, on va utiliser la régression Ridge, c'est une régression linéaire avec une contrainte quadratique sur les coefficients. C’est utile lorsque les variables sont très corrélées, ce qui fausse souvent la résolution numérique. La solution peut s’exprimer de façon exacte. On peut donc résoudre alors des problèmes de colinéarité.

# %% [markdown]
# <a name="Random"></a>
# # Random Forest:
#
# Voici le <A HREF="./1p4QVeBl7AB6Ef0HwvEXjeJQz35Te9_r_"> Notebook de Random Forest</A>
#
#
#
# C'est une technique de Machine Learning très populaire auprès des Data Scientists et pour cause : elle présente de nombreux avantages comparé aux autres algorithmes de data.
# C’est une technique facile à interpréter, stable, qui présente en général de bonnes accuracies et qui peut être utilisée pour des tâches de régression ou de classification. Elle couvre donc une grande partie des problèmes de Machine Learning.
#
# Une forêt aléatoire permet d'appliquer une régression. Reposant sur un système de bagging (voir plus haut), le random forest de régression consiste schématiquement à calculer la moyenne des prévisions obtenues par l'ensemble des estimations des arbres décisionnels de la forêt aléatoire.

# %% [markdown]
# <a name="Boost"></a>
# # XGBoost:
#
# Voici le <A HREF="./1Xt65DJOLek8lwT20sxC7HWQwf5Mzij7C#scrollTo=Y8Oz93gmMVMH"> Notebook XGBoost</A>
#
# Le Boosting de Gradient est un algorithme d’apprentissage supervisé dont le principe et de combiner les résultats d’un ensemble de modèles plus simple et plus faibles afin de fournir une meilleur prédiction.
#
# On parle d’ailleurs de méthode d’agrégation de modèles. L’idée est donc simple : au lieu d’utiliser un seul modèle, l’algorithme va en utiliser plusieurs qui serons ensuite combinés pour obtenir un seul résultat.
#
# C’est avant tout une approche pragmatique qui permet donc de gérer des problèmes de régression comme de classification.

# %% [markdown]
# <a name="mod"></a>
# # Comparatif des modèles:
#
# On va comparer les métriques pour chaque modèle et confirmer que la méthode RandomForest est la meilleure dans notre cas.
#
# Voici le <A HREF="./1NFH91DO25LnwvUr9y9JvYAY5fJUNXk92"> Notebook.

# %% [markdown]
# <a name="moda"></a>
# # Influence de l'Energy Star Score:
#
# On va observer l'influence de l'Energy Star Score. On en conclut qu'il n'a pas vraiment d'influence dans nos prédictions.
#
# Voici le <A HREF="./1jinCu_hM6zmAhy7mw7KJyExioZiBUsJx#scrollTo=pgn9XZHhx5O5"> Notebook.

# %% [markdown]
# <a name="moda"></a>
# # Conclusion:
#
# On conclut par le fait que la méthode Random Forest nous a permis de faire des prédictions fiables.
# Cependant, on a beaucoup de données manquantes et il serait judicieux de demander plus d'informations à la mairie de Seattle sur les immeubles , notamment en construction, et voir s'ils ont éte finis.
#
# On pourrait également se renseigner sur les immeubles ayant un panneau solaire et les prendre en compte étant donné qu'ils produisent de l'énergie solaire.
#
# Enfin, on aurait pu eventuellment penser à explorer plus d'algorithmes et voir si une méthode aurait pu nous donner de meilleurs résultats, ce qu'on a pas pu faire ici par contrainte de temps.
